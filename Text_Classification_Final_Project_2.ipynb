# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# %%
nltk.download('popular')

# %%
pip install nltk

# %%
pip install PySastrawi

# %%
pip install Sastrawi

# %% [markdown]
# ## Read & Preprocessing Data

# %% [markdown]
# ###Load Data Dari Github

# %%
# !git clone https://github.com/sabarmitikap/Text_Classification_NLP
# Out:
# Cloning into 'Text_Classification_NLP'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
with open("/content/Text_Classification_NLP/Berita_Informatika_Sample.txt", "r") as text:
  data = text.read()

print(data[:300])
# Out:
# beberapa tahun terakhir jurusan teknik informatika menjadi salah satu jurusan favorit banyak orang atas dasar cerahnya jaminan karier di masa depan teknik informatika berhasil membuat banyak orang berlomba lomba mempelajari ilmu tentang komputer dan bahasa pemograman ini tapi tunggu dulu nih kalau k

# %% [markdown]
# ###Read Data

# %%
print(data[:300])
# Out:
# beberapa tahun terakhir jurusan teknik informatika menjadi salah satu jurusan favorit banyak orang atas dasar cerahnya jaminan karier di masa depan teknik informatika berhasil membuat banyak orang berlomba lomba mempelajari ilmu tentang komputer dan bahasa pemograman ini tapi tunggu dulu nih kalau k

# %% [markdown]
# ###Preprocess Data

# %%
word_tokens = word_tokenize(data)
print(word_tokens)
# Out:
# ['beberapa', 'tahun', 'terakhir', 'jurusan', 'teknik', 'informatika', 'menjadi', 'salah', 'satu', 'jurusan', 'favorit', 'banyak', 'orang', 'atas', 'dasar', 'cerahnya', 'jaminan', 'karier', 'di', 'masa', 'depan', 'teknik', 'informatika', 'berhasil', 'membuat', 'banyak', 'orang', 'berlomba', 'lomba', 'mempelajari', 'ilmu', 'tentang', 'komputer', 'dan', 'bahasa', 'pemograman', 'ini', 'tapi', 'tunggu', 'dulu', 'nih', 'kalau', 'kamu', 'salah', 'satu', 'orang', 'yang', 'tertarik', 'masuk', 'jurusan', 'ini', 'ada', 'baiknya', 'kalau', 'menyimak', 'terlebih', 'dahulu', 'tentang', 'apa', 'saja', 'skill', 'dasar', 'yang', 'harus', 'dimiliki', 'biar', 'nanti', 'gak', 'kaget', 'dan', 'bisa', 'mempersiapkan', 'dari', 'jauh-jauh', 'hari', 'yuk', 'berikut', 'lima', 'skill', 'dasar', 'yang', 'harus', 'dimiliki', 'mahasiswa', 'teknik', 'informatika', 'dalam', 'jurusan', 'ini', 'kita', 'akan', 'dihadapkan', 'dengan', 'berbagai', 'bahasa', 'pemograman', 'meskipun', 'memiliki', 'perbedaan', 'dalam', 'segi', 'model', 'dan', 'penulisan', 'namun', 'sebenarnya', 'semua', 'bahasa', 'pemograman', 'memiliki', 'satu', 'kunci', 'utama', 'yaitu', 'logika', 'kita', 'membutuhkan', 'penguasaan', 'logika', 'atau', 'pola', 'pikir', 'yang', 'sistematis', 'dengan', 'berbekal', 'kemampuan', 'ini', 'dijamin', 'kalian', 'akan', 'mudah', 'mengerti', 'dan', 'mengikuti', 'pelajaran', 'yang', 'ada', 'teknik', 'informatika', 'bukan', 'hanya', 'tentang', 'koding', 'dan', 'bahasa', 'pemrograman', 'loh', 'karena', 'di', 'balik', 'semua', 'itu', 'kita', 'dituntut', 'untuk', 'bisa', 'merancang', 'sebuah', 'program', 'yang', 'membutuhkan', 'tampilan', 'yang', 'menarik', 'kalau', 'kamu', 'beruntung', 'dengan', 'memiliki', 'kemampuan', 'logika', 'dan', 'kreativitas', 'yang', 'bagus', 'maka', 'kamu', 'akan', 'sangat', 'terbantu', 'selama', 'proses', 'kuliah', 'berlangsung']

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['jurusan', 'teknik', 'informatika', 'salah', 'jurusan', 'favorit', 'orang', 'dasar', 'cerahnya', 'jaminan', 'karier', 'teknik', 'informatika', 'berhasil', 'orang', 'berlomba', 'lomba', 'mempelajari', 'ilmu', 'komputer', 'bahasa', 'pemograman', 'tunggu', 'nih', 'salah', 'orang', 'tertarik', 'masuk', 'jurusan', 'baiknya', 'menyimak', 'skill', 'dasar', 'dimiliki', 'biar', 'gak', 'kaget', 'jauh-jauh', 'yuk', 'skill', 'dasar', 'dimiliki', 'mahasiswa', 'teknik', 'informatika', 'jurusan', 'dihadapkan', 'bahasa', 'pemograman', 'memiliki', 'perbedaan', 'segi', 'model', 'penulisan', 'bahasa', 'pemograman', 'memiliki', 'kunci', 'utama', 'logika', 'membutuhkan', 'penguasaan', 'logika', 'pola', 'pikir', 'sistematis', 'berbekal', 'kemampuan', 'dijamin', 'mudah', 'mengerti', 'mengikuti', 'pelajaran', 'teknik', 'informatika', 'koding', 'bahasa', 'pemrograman', 'loh', 'dituntut', 'merancang', 'program', 'membutuhkan', 'tampilan', 'menarik', 'beruntung', 'memiliki', 'kemampuan', 'logika', 'kreativitas', 'bagus', 'terbantu', 'proses', 'kuliah']

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata_1.most_common(20))
print()
print(freq_kata_2.most_common(20))
# Out:
# [('yang', 8), ('dan', 6), ('jurusan', 4), ('teknik', 4), ('informatika', 4), ('bahasa', 4), ('ini', 4), ('satu', 3), ('orang', 3), ('dasar', 3), ('tentang', 3), ('pemograman', 3), ('kalau', 3), ('kamu', 3), ('kita', 3), ('akan', 3), ('dengan', 3), ('memiliki', 3), ('logika', 3), ('salah', 2)]
#
# [('jurusan', 4), ('teknik', 4), ('informatika', 4), ('bahasa', 4), ('orang', 3), ('dasar', 3), ('pemograman', 3), ('memiliki', 3), ('logika', 3), ('salah', 2), ('skill', 2), ('dimiliki', 2), ('membutuhkan', 2), ('kemampuan', 2), ('favorit', 1), ('cerahnya', 1), ('jaminan', 1), ('karier', 1), ('berhasil', 1), ('berlomba', 1)]

# %% [markdown]
# ##Hasil & Kesimpulan

# %%
import matplotlib.pyplot as plt

# %%
freq_kata_1.plot(20)
freq_kata_2.plot(20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

freqdist1 = nltk.FreqDist(word_tokens_no_stopwords)
freqdist1.plot(25)
plt.show()
